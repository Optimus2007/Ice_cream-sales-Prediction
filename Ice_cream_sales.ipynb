# %% [markdown]
# <a href="https://colab.research.google.com/github/Optimus2007/Ice_cream-sales-Prediction/blob/main/Ice_cream_sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Polynomial Regression**

# %% [markdown]
# Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Importing the dataset

# %%
dataset = pd.read_csv('Ice_cream selling data.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# Visualising the Linear Regression results

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg.predict(X), color = 'blue')
plt.title('Temperature vs Ice cream Sales (Linear Regression)')
plt.xlabel('Temperature')
plt.ylabel('Ice cream Sales(units)')
plt.show()

# %% [markdown]
# Visualising the Polynomial Regression results

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg_2.predict(poly_reg.fit_transform(X)), color = 'blue')
plt.title('Temperature vs Ice cream Sales (Linear Regression)')
plt.xlabel('Temperature')
plt.ylabel('Ice cream Sales(units)')
plt.show()

# %% [markdown]
# Predicting a new result with Linear Regression

# %%
lin_reg.predict([[2.34]])
# Out:
# array([14.25803975])

# %% [markdown]
# Predicting a new result with Polynomial Regression

# %%
lin_reg_2.predict(poly_reg.fit_transform([[2.34]]))
# Out:
# array([10.74860029])
